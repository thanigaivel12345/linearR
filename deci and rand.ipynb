# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import sklearn



df=pd.read_csv("TaxiFare.csv")
display(df)
# Out:
#       unique_id      date_time_of_pickup  longitude_of_pickup  \
# 0       26:21.0  2009-06-15 17:26:21 UTC           -73.844311
# 1       52:16.0  2010-01-05 16:52:16 UTC           -74.016048
# 2       35:00.0  2011-08-18 00:35:00 UTC           -73.982738
# 3       30:42.0  2012-04-21 04:30:42 UTC           -73.987130
# 4       51:00.0  2010-03-09 07:51:00 UTC           -73.968095
# ...         ...                      ...                  ...
# 49995   25:15.0  2013-06-12 23:25:15 UTC           -73.999973
# 49996   19:18.0  2015-06-22 17:19:18 UTC           -73.984756
# 49997   53:00.0  2011-01-30 04:53:00 UTC           -74.002698
# 49998   09:00.0  2012-11-06 07:09:00 UTC           -73.946062
# 49999   13:14.0  2010-01-13 08:13:14 UTC           -73.932603
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0               40.721319            -73.841610            40.712278
# 1               40.711303            -73.979268            40.782004
# ...

# %%
df2=pd.read_csv("h1n1_vaccine_prediction.csv")
display(df2)
# Out:
#        unique_id  h1n1_worry  h1n1_awareness  antiviral_medication  \
# 0              0         1.0             0.0                   0.0
# 1              1         3.0             2.0                   0.0
# 2              2         1.0             1.0                   0.0
# 3              3         1.0             1.0                   0.0
# 4              4         2.0             1.0                   0.0
# ...          ...         ...             ...                   ...
# 26702      26702         2.0             0.0                   0.0
# 26703      26703         1.0             2.0                   0.0
# 26704      26704         2.0             2.0                   0.0
# 26705      26705         1.0             1.0                   0.0
# 26706      26706         0.0             0.0                   0.0
#
#        contact_avoidance  bought_face_mask  wash_hands_frequently  \
# 0                    0.0               0.0                    0.0
# ...

# %%
x=a.drop("h1n1_vaccine",axis=1)
y=a["h1n1_vaccine"]

from sklearn.preprocessing import LabelEncoder
a=df2.apply(LabelEncoder().fit_transform)
a
# Out:
#        unique_id  h1n1_worry  h1n1_awareness  antiviral_medication  \
# 0              0           1               0                     0
# 1              1           3               2                     0
# 2              2           1               1                     0
# 3              3           1               1                     0
# 4              4           2               1                     0
# ...          ...         ...             ...                   ...
# 26702      26702           2               0                     0
# 26703      26703           1               2                     0
# 26704      26704           2               2                     0
# 26705      26705           1               1                     0
# 26706      26706           0               0                     0
#
#        contact_avoidance  bought_face_mask  wash_hands_frequently  \
# 0                      0                 0                      0
# ...

# %%
purchased=a[a.h1n1_vaccine==0].h1n1_vaccine.count()
notpurchased=a[a.h1n1_vaccine==1].h1n1_vaccine.count()
plt.bar(0,purchased,label='no')
plt.bar(1,notpurchased,label='yes')
plt.xticks([])
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
x_smot, y_smot = oversample.fit_resample(x, y)

# %%
purchased=y_smot[y_smot==0].count()
notpurchased=y_smot[y_smot==1].count()
plt.bar(0,purchased,label='no')
plt.bar(1,notpurchased,label='yes')
plt.xticks([])
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,y_train,x_test,y_test=train_test_split(x,y,train_size=0.8,random_state=1)
x_train.shape,y_train.shape
# Out:
# ((21365, 33), (5342, 33))

# %%
from sklearn.tree import DecisionTreeClassifier
c=DecisionTreeClassifier(criterion="gini",max_depth=3,random_state=0)
x=c.fit(x_smot,y_smot)

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(90,20))
plot_tree(c,feature_names=list(x_smot.columns))
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=50,criterion="gini",max_depth=3)
m=rf.fit(x_smot,y_smot)

# %%
plt.figure(figsize=(50,30))
plot_tree(rf.estimators_[2],feature_names=x_smot.columns)
# Out:
# [Text(0.5, 0.875, 'dr_recc_seasonal_vacc <= 1.5\ngini = 0.5\nsamples = 26511\nvalue = [21221, 20845]'),
#  Text(0.25, 0.625, 'sex <= 0.5\ngini = 0.499\nsamples = 25098\nvalue = [19151, 20662]'),
#  Text(0.125, 0.375, 'reduced_outside_home_cont <= 0.5\ngini = 0.483\nsamples = 17338\nvalue = [11247, 16242]'),
#  Text(0.0625, 0.125, 'gini = 0.456\nsamples = 12992\nvalue = [7256, 13352]'),
#  Text(0.1875, 0.125, 'gini = 0.487\nsamples = 4346\nvalue = [3991, 2890]'),
#  Text(0.375, 0.375, 'is_seas_risky <= 1.5\ngini = 0.46\nsamples = 7760\nvalue = [7904, 4420]'),
#  Text(0.3125, 0.125, 'gini = 0.368\nsamples = 4355\nvalue = [5246, 1688]'),
#  Text(0.4375, 0.125, 'gini = 0.5\nsamples = 3405\nvalue = [2658, 2732]'),
#  Text(0.75, 0.625, 'antiviral_medication <= 0.5\ngini = 0.149\nsamples = 1413\nvalue = [2070, 183]'),
#  Text(0.625, 0.375, 'is_h1n1_risky <= 2.5\ngini = 0.137\nsamples = 1345\nvalue = [1986, 159]'),
#  Text(0.5625, 0.125, 'gini = 0.081\nsamples = 901\nvalue = [1376, 61]'),
# ...

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=1,solver="liblinear",multi_class='ovr')
k=lr.fit(x_smot,y_smot)
k
# Out:
# LogisticRegression(C=1, multi_class='ovr', solver='liblinear')

# %%
from sklearn.metrics import confusion_matrix
y_pred=lr.predict(x_smot)
cnf=confusion_matrix(y_smot,y_pred)
cnf
# Out:
# array([[16617,  4416],
#        [ 4088, 16945]], dtype=int64)

# %%
from sklearn import metrics
metrics.accuracy_score(y_smot,y_pred)
metrics.precision_score(y_smot,y_pred)
metrics.recall_score(y_smot,y_pred)
metrics.f1_score(y_smot,y_pred)
# Out:
# 0.7994055762607916
